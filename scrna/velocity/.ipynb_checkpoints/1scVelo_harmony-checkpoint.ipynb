# %%
import scvelo as scv
import scanpy as sc
import cellrank as cr
import numpy as np
import pandas as pd
import anndata as ad

# %%
scv.settings.verbosity = 3
scv.settings.set_figure_params('scvelo', facecolor='white', dpi=100, frameon=False,
                              figsize = [5,5])
cr.settings.verbosity = 2
rc2_loom_path = '/project/gca/yuzhao1/work/final_RC2rna/upstream/'
gca_loom_path = '/project/gca/yuzhao1/work/final_GCArna/upstream/'
input_path = '/project/gca/yuzhao1/work/final_RC2rna/velocity/epithelial/'
SampleIDs = pd.read_csv("/project/gca/yuzhao1/work/final_RC2rna/metadata/SampleIDs.csv")['SampleID']

# %%
######################## part 1: process ##########################

# %%
# loomdata = []
# for i in SampleIDs:
#     if('PP' in i or 'POU' in i):
#         temp = scv.read(rc2_loom_path + i + '/velocyto/' + i + '.loom', cache=True)
#     if('TI' in i or 'AC' in i):
#         temp = scv.read(gca_loom_path + i + '/velocyto/' + i + '.loom', cache=True)
#     barcodes = [bc.replace(':','_').replace('x','-1') for bc in temp.obs.index.tolist()]
#     temp.obs.index = barcodes
#     temp.var_names_make_unique()
#     loomdata.append(temp)

# %%
# # concatenate the looms
# loomdata_union = ad.concat(loomdata)

# %%
# # save
# import pickle
# filename = input_path+'loomdata_union.pkl'
# pickle.dump(loomdata_union, 
#             open(filename, 'wb'))

# %%
import pickle
filename = input_path+'loomdata_union.pkl'
loomdata_union = pickle.load(open(filename, 'rb'))

# %%
# merge matrices into the original adata object
adata = sc.read_h5ad(input_path+'adata_input.h5ad')
# add metadata and visualize
cell_meta = pd.read_csv(input_path+"metadata.csv")
adata.obs['anno1'] = cell_meta['anno1'].values

# %%
adata = scv.utils.merge(adata, loomdata_union)

# %%
# plot umap to check
sc.pl.umap(adata, color='anno1', frameon=False, legend_loc='on data', title='', save=None)

# %%
scv.pl.proportions(adata, groupby='anno1', save='_all.png')
# Out:
# saving figure to file ./figures/scvelo_proportions__all.png

# %%
scv.pp.filter_and_normalize(adata, min_shared_counts=20, n_top_genes=2000)
# Out:
# Filtered out 10875 genes that are detected 20 counts (shared).
# WARNING: Did not normalize X as it looks processed already. To enforce normalization, set `enforce=True`.
# Normalized count data: spliced, unspliced.
# Extracted 2000 highly variable genes.
# WARNING: Did not modify X as it looks preprocessed already.

# %%
# use a copy to calculate harmony_pca in this subset
# using subset because otherwise the X will be subset by variable genes
tempann = adata.copy()

# %%
# scv.pp.normalize_per_cell(tempann, enforce=True) 
# scv.pp.log1p(tempann)
# sc.pp.highly_variable_genes(tempann, min_mean=0.0125, max_mean=3, min_disp=0.5)
# sum(tempann.var.highly_variable)
# tempann = tempann[:, tempann.var.highly_variable]

# %%
sc.pp.regress_out(tempann, ['nCount_RNA', 'percent.mt', 'CC.Difference'])
sc.pp.scale(tempann, max_value=10)
sc.tl.pca(tempann, svd_solver='arpack', n_comps=50)
import scanpy.external as sce
sce.pp.harmony_integrate(tempann, 'Patient_ID', max_iter_harmony = 20)
adata.obsm['X_pca'] = tempann.obsm['X_pca_harmony']
adata.obsm['X_pca']
# Out:
# 2022-11-20 20:47:41,014 - harmonypy - INFO - Iteration 1 of 20
# 2022-11-20 20:47:55,946 - harmonypy - INFO - Iteration 2 of 20
# 2022-11-20 20:48:10,711 - harmonypy - INFO - Iteration 3 of 20
# 2022-11-20 20:48:26,367 - harmonypy - INFO - Iteration 4 of 20
# 2022-11-20 20:48:42,111 - harmonypy - INFO - Iteration 5 of 20
# 2022-11-20 20:48:57,458 - harmonypy - INFO - Iteration 6 of 20
# 2022-11-20 20:49:13,047 - harmonypy - INFO - Iteration 7 of 20
# 2022-11-20 20:49:27,036 - harmonypy - INFO - Iteration 8 of 20
# 2022-11-20 20:49:42,013 - harmonypy - INFO - Converged after 8 iterations
# array([[ 2.5331198e+01,  1.6345785e+01, -7.9538560e+00, ...,
#          3.8830962e+00,  2.2642205e+00,  1.4872423e+00],
#        [ 7.3857093e+00,  4.8049006e+00, -4.8148248e-01, ...,
#          5.5165029e-01, -8.7345384e-02, -2.6309386e-01],
#        [ 3.9275551e+00, -4.9198713e+00,  1.3776285e+01, ...,
#          1.0518020e+00, -1.6782334e+00,  9.3130106e-01],
#        ...,
#        [ 3.1968862e-01, -4.1865820e-01, -1.6059625e+00, ...,
#          1.2354854e+00, -1.4830209e-01, -3.0719141e-02],
#        [ 1.9435101e+01,  3.5772907e+01, -7.4996572e+00, ...,
#          1.0740711e-01,  1.9672852e+00, -4.5101482e-02],
#        [ 1.8539062e+01, -1.1349691e+01, -7.6431715e-01, ...,
#         -1.2848027e+00,  3.0867413e-01,  9.7264272e-01]], dtype=float32)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 59751 × 2000
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample_ID', 'Doublet_score', 'biopsy_location', 'Patient_ID', 'percent.mt', 'percent.rb', 'log10GenesPerUMI', 'S.Score', 'G2M.Score', 'Phase', 'CC.Difference', 'Sample_ID_Corrected', 'category1', 'RNA_snn_res.0.5', 'seurat_clusters', 'seurat_clusters_res0.5', 'RNA_snn_res.0.8', 'seurat_clusters_res0.8', 'RNA_snn_res.1', 'seurat_clusters_res1', 'RNA_snn_res.1.2', 'seurat_clusters_res1.2', 'RNA_snn_res.1.5', 'seurat_clusters_res1.5', 'RNA_snn_res.2', 'seurat_clusters_res2', 'RNA_snn_res.2.5', 'seurat_clusters_res2.5', 'anno1', 'embedding1', 'embedding2', 'barcode', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_counts'
#     var: 'means', 'dispersions', 'dispersions_norm', 'highly_variable'
#     uns: 'anno1_colors'
#     obsm: 'X_harmony_umap', 'X_pca', 'X_umap'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
# necessary because I have transfer it from seurat
sc.pp.neighbors(adata, n_neighbors=30, use_rep='X_pca')
scv.pp.moments(adata, n_pcs=30, n_neighbors=30)
# Out:
# computing moments based on connectivities
#     finished (0:00:07) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)

# %%
sc.tl.umap(adata)

# %%
# sc.pl.umap(adata, color=['anno1'], legend_loc='on data', title='', frameon=False, save=None)
sc.pl.umap(adata, color=['anno1'], title='', frameon=False, save=None)

# %%
######################## part 2.1: Run dynamical model ##########################

# %%
# dynamics model requires to run scv.tl.recover_dynamics(adata, **params) beforehand
scv.tl.recover_dynamics(adata, n_jobs=4)

# compute velocity
scv.tl.velocity(adata, mode='dynamical', diff_kinetics=True)


# !jupyter nbextension enable --py widgetsnbextension

scv.tl.velocity_graph(adata, n_neighbors=10, n_jobs=4)

scv.settings.set_figure_params('scvelo', facecolor='white', dpi=100, frameon=False,
                              figsize = [5,5])

# %%
scv.pl.velocity_embedding_grid(adata, basis='umap', color='anno1', 
                               save=False, title='', scale=0.2)

# %%
scv.pl.velocity_embedding_stream(adata, basis='umap', color=['anno1'],  density=3, cutoff_perc=5,
                                 save=False, title='')

# %%
# save dataset as anndata format
adata.write(input_path+'adata_dynamical_output.h5ad')

# %%
######################## part 2.2: Run stochastic model with differential kinetics ###############

# %%
scv.tl.velocity(adata, diff_kinetics=True, mode='stochastic')

# !jupyter nbextension enable --py widgetsnbextension

scv.tl.velocity_graph(adata, n_neighbors=10, n_jobs=4)

scv.settings.set_figure_params('scvelo', facecolor='white', dpi=100, frameon=False,
                              figsize = [5,5])
# Out:
# computing velocities
#     finished (0:00:20) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK
# computing velocity graph (using 4/48 cores)
#   0%|          | 0/59751 [00:00<?, ?cells/s]
# /home/yuzhao1/yuzhao1/software/conda/gca-env/lib/python3.8/site-packages/scvelo/core/_parallelize.py:138: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   res = np.array(res) if as_array else res
#     finished (0:00:21) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %%
scv.pl.velocity_embedding_grid(adata, basis='umap', color='anno1', 
                               save=False, title='', scale=0.2)
# Out:
# computing velocity embedding
#     finished (0:00:11) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)

# %%
scv.pl.velocity_embedding_stream(adata, basis='X_harmony_umap', color=['anno1'], density=2,
                                 save=False, title='')
# Out:
# computing velocity embedding
#     finished (0:00:11) --> added
#     'velocity_harmony_umap', embedded velocity vectors (adata.obsm)

# %%
# save dataset as anndata format
adata.write(input_path+'adata_stochastic_output.h5ad')

# %%
######################## part 3: visualize ##########################

# %%
# reload dataset
# adata = sc.read_h5ad(input_path+'adata_output.h5ad')

# %%
# reload stochastic data
adata = sc.read_h5ad(input_path+'adata_stochastic_output.h5ad')

# %%
# # load new umap from cell metadata:
# cell_meta = pd.read_csv(input_path+"metadata.csv")
# adata.obsm['X_umap'] = np.vstack((cell_meta['embedding1'].to_numpy(), cell_meta['embedding2'].to_numpy())).T

# %%
scv.settings.set_figure_params('scvelo', facecolor='white', dpi=100, frameon=False,
                              figsize = [5,5])

# %%
scv.pl.velocity_embedding_grid(adata, basis='umap', color='anno1', 
                               save=False, title='', scale=0.2)

# %%
scv.pl.velocity_embedding_stream(adata, basis='umap', color=['anno1'], 
                                 save=False, title='')

# %%
############### part 4: downstream analysis ###############

# %%
x = adata.var.index[np.where(adata.var['velocity_genes'] )]
np.savetxt("epithelial/velocity_genes.csv", x, delimiter=",", fmt='%s')

# %%
# waiting for libtbb
import cellrank
cellrank.tl.terminal_states(adata) # this is an improved version of scVelo

# %%
scv.tl.velocity_clusters(adata)
scv.pl.scatter(adata, color='velocity_clusters')

# %%
scv.tl.rank_velocity_genes(adata, groupby='anno1', min_corr=.3)

# %%
df = scv.DataFrame(adata.uns['rank_velocity_genes']['names'])
df.head(20)

# %%
adata

# %%
scv.pl.velocity(adata, ["SATB2","TFCP2L1","PPARG","ZBTB10"], color='anno1',
                ncols=1, save = '_markers_all.png', dpi=300)

# %%
scv.pl.scatter(adata, 'LGR5', color=['anno1', 'velocity'])

# %%
scv.pl.velocity(adata, ['LGR5'], ncols=1, color='anno1')

# %%
df = adata.var
df = df[(df['fit_likelihood'] > .1) & df['velocity_genes'] == True]

kwargs = dict(xscale='log', fontsize=16)
with scv.GridSpec(ncols=3) as pl:
    pl.hist(df['fit_alpha'], xlabel='transcription rate', **kwargs)
    pl.hist(df['fit_beta'] * df['fit_scaling'], xlabel='splicing rate', xticks=[.1, .4, 1], **kwargs)
    pl.hist(df['fit_gamma'], xlabel='degradation rate', xticks=[.1, .4, 1], **kwargs)

scv.get_df(adata, 'fit*', dropna=True).head()

# %%
scv.tl.rank_velocity_genes(adata, groupby='anno1', min_corr=.3)

# %%
df = scv.DataFrame(adata.uns['rank_velocity_genes']['names'])
df.head(20)

# %%
top_genes = adata.var['fit_likelihood'].sort_values(ascending=False).index)

# %%
scv.pl.scatter(adata, color='anno1', basis=top_genes[:15], ncols=5, frameon=False)

# %%
top_genes

# %%
############### part 5: cellrank ###############
# not suitable for our dataset, they lack a general adaptability

# %%
adata = sc.read_h5ad(input_path+'adata_stochastic_output.h5ad')

# %%
import cellrank as cr
import tbb

# %%
cr.tl.terminal_states(adata, cluster_key="anno1", weight_connectivities=0.2)

# %%
cr.pl.terminal_states(adata)

# %%
cr.tl.initial_states(adata, cluster_key="anno1")
cr.pl.initial_states(adata, discrete=True)

# %%
cr.tl.lineages(adata)
cr.pl.lineages(adata, same_plot=False)

# %%
cr.pl.lineages(adata, same_plot=True)

# %%
scv.tl.recover_latent_time(
    adata, root_key="initial_states_probs", end_key="terminal_states_probs"
)

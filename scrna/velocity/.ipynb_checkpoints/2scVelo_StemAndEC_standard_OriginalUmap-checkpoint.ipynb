# %%
import scvelo as scv
import scanpy as sc
import cellrank as cr
import numpy as np
import pandas as pd
import anndata as ad

# %%
scv.settings.verbosity = 3
scv.settings.set_figure_params('scvelo', facecolor='white', dpi=100, frameon=False,
                              figsize = [5,5])
scv.settings.presenter_view = True  # set max width size for presenter view
scv.settings.set_figure_params('scvelo')  # for beautified visualization

# %%
input_path = '/project/gca/yuzhao1/work/final_RC2rna/velocity/epithelial/ec_stem/'
input_path_raw = '/project/gca/yuzhao1/work/final_RC2rna/velocity/epithelial/'

# %%
######################## part 1: process ##########################

# %%
adata = sc.read_h5ad(input_path_raw+'adata_input.h5ad')
# add metadata and visualize
cell_meta = pd.read_csv(input_path_raw+"metadata.csv")
adata.obs['anno1'] = cell_meta['anno1'].values
adata = adata[adata.obs['anno1'].isin(['EC1', 'EC2', 'Stem'])]

# %%
import pickle
filename = input_path_raw+'loomdata_union.pkl'
loomdata_union = pickle.load(open(filename, 'rb'))

# %%
adata = scv.utils.merge(adata, loomdata_union)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 43358 × 22103
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample_ID', 'Doublet_score', 'biopsy_location', 'Patient_ID', 'percent.mt', 'percent.rb', 'log10GenesPerUMI', 'S.Score', 'G2M.Score', 'Phase', 'CC.Difference', 'Sample_ID_Corrected', 'category1', 'RNA_snn_res.0.5', 'seurat_clusters', 'seurat_clusters_res0.5', 'RNA_snn_res.0.8', 'seurat_clusters_res0.8', 'RNA_snn_res.1', 'seurat_clusters_res1', 'RNA_snn_res.1.2', 'seurat_clusters_res1.2', 'RNA_snn_res.1.5', 'seurat_clusters_res1.5', 'RNA_snn_res.2', 'seurat_clusters_res2', 'RNA_snn_res.2.5', 'seurat_clusters_res2.5', 'anno1_grouped', 'embedding1', 'embedding2', 'barcode', 'anno1', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size'
#     uns: 'anno1_grouped_colors'
#     obsm: 'X_harmony', 'X_harmony_UMAP', 'X_pca', 'X_umap'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'

# %%
# plot umap to check
sc.pl.umap(adata, color='anno1', frameon=False, legend_loc='on data', title='', save=False)

# %%
scv.pl.proportions(adata, groupby='anno1')

# %%
# pre-process, pre-filter all tiny noises
scv.pp.filter_genes(adata, min_shared_counts=10)

# normalize X, spliced and unspliced
scv.pp.normalize_per_cell(adata, enforce=True) 

# get highly variable genes
scv.pp.filter_genes_dispersion(adata, n_top_genes=2000)

# only log the X
scv.pp.log1p(adata)

adata
# Out:
# Filtered out 10969 genes that are detected 10 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 2000 highly variable genes.
# AnnData object with n_obs × n_vars = 43358 × 2000
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample_ID', 'Doublet_score', 'biopsy_location', 'Patient_ID', 'percent.mt', 'percent.rb', 'log10GenesPerUMI', 'S.Score', 'G2M.Score', 'Phase', 'CC.Difference', 'Sample_ID_Corrected', 'category1', 'RNA_snn_res.0.5', 'seurat_clusters', 'seurat_clusters_res0.5', 'RNA_snn_res.0.8', 'seurat_clusters_res0.8', 'RNA_snn_res.1', 'seurat_clusters_res1', 'RNA_snn_res.1.2', 'seurat_clusters_res1.2', 'RNA_snn_res.1.5', 'seurat_clusters_res1.5', 'RNA_snn_res.2', 'seurat_clusters_res2', 'RNA_snn_res.2.5', 'seurat_clusters_res2.5', 'anno1_grouped', 'embedding1', 'embedding2', 'barcode', 'anno1', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_counts'
#     var: 'gene_count_corr', 'means', 'dispersions', 'dispersions_norm', 'highly_variable'
#     uns: 'anno1_grouped_colors', 'anno1_colors'
#     obsm: 'X_harmony', 'X_harmony_UMAP', 'X_pca', 'X_umap'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'

# %%
adata.obsm['X_pca']
# Out:
# array([[ -3.8276785 ,  -5.08923722,  -5.1749894 , ...,  -1.06727609,
#           0.13957636,   0.73684521],
#        [ -7.18647538, -10.08924476,  -0.97530322, ...,  -0.63644649,
#           2.01825233,  -0.78536495],
#        [ -9.70760693, -12.84707379,  -2.07941701, ...,  -1.74876727,
#          -0.5542233 ,   0.73370166],
#        ...,
#        [  7.87847546,  -1.09270672,   1.29951199, ...,   0.56116459,
#           0.10892635,  -0.50434673],
#        [ -2.12877859,  -2.56455066,   0.43787464, ...,  -0.40716427,
#          -0.90844834,   1.41896689],
#        [-15.78945851,  -8.138341  ,  -1.24755265, ...,  -1.01046665,
#           0.11465212,   1.87718366]])

# %%
# use a copy to calculate harmony_pca in this subset
# using subset because otherwise the X will be subset by variable genes
tempann = adata.copy()
#sc.pp.highly_variable_genes(tempann, min_mean=0.0125, max_mean=3, min_disp=0.5)
#sc.pl.highly_variable_genes(tempann)
#tempann = tempann[:, tempann.var.highly_variable]
sc.pp.regress_out(tempann, ['nCount_RNA', 'percent.mt', 'CC.Difference'])
sc.pp.scale(tempann, max_value=10)
sc.tl.pca(tempann, svd_solver='arpack', n_comps=50)
import scanpy.external as sce
sce.pp.harmony_integrate(tempann, 'Patient_ID', max_iter_harmony = 20)
adata.obsm['X_pca'] = tempann.obsm['X_pca_harmony']
adata.obsm['X_pca']
# Out:
# 2022-11-13 23:32:31,025 - harmonypy - INFO - Iteration 1 of 20
# 2022-11-13 23:32:41,438 - harmonypy - INFO - Iteration 2 of 20
# 2022-11-13 23:32:51,836 - harmonypy - INFO - Iteration 3 of 20
# 2022-11-13 23:33:02,237 - harmonypy - INFO - Iteration 4 of 20
# 2022-11-13 23:33:12,633 - harmonypy - INFO - Iteration 5 of 20
# 2022-11-13 23:33:23,010 - harmonypy - INFO - Iteration 6 of 20
# 2022-11-13 23:33:30,682 - harmonypy - INFO - Iteration 7 of 20
# 2022-11-13 23:33:37,994 - harmonypy - INFO - Iteration 8 of 20
# 2022-11-13 23:33:44,314 - harmonypy - INFO - Iteration 9 of 20
# 2022-11-13 23:33:49,217 - harmonypy - INFO - Iteration 10 of 20
# 2022-11-13 23:33:54,135 - harmonypy - INFO - Iteration 11 of 20
# 2022-11-13 23:33:58,828 - harmonypy - INFO - Iteration 12 of 20
# 2022-11-13 23:34:03,491 - harmonypy - INFO - Converged after 12 iterations
# array([[-2.8814703e-01, -6.1970663e+00, -2.6251183e+00, ...,
#          3.9325736e-02, -1.3365027e+00, -8.2604602e-02],
#        [ 5.5304012e+00, -8.4452305e+00,  3.3673749e+00, ...,
#         -8.6841697e-01,  4.0878439e-01,  5.3034633e-01],
#        [-7.3721571e+00, -9.8215446e+00,  2.5261598e+00, ...,
#         -9.4474041e-01,  6.0304850e-01, -4.3939289e-01],
#        ...,
#        [-4.9857206e+00,  4.5249166e+00,  1.0889652e+00, ...,
#         -5.3158419e-05,  5.3439617e-01, -3.6115491e-01],
#        [-1.0023744e+01, -5.9294701e+00,  3.5010927e+00, ...,
#          8.9657515e-01, -1.1601067e+00,  4.4183046e-01],
#        [-1.3653647e+01, -1.7554152e+01,  7.1425633e+00, ...,
#          7.1564209e-01,  1.7860210e-01,  6.6882455e-01]], dtype=float32)

# %%
# necessary because I have transfer it from seurat
sc.pp.neighbors(adata, n_neighbors=30, use_rep='X_pca')

scv.pp.moments(adata, use_rep='X_pca', n_pcs=50, 
               n_neighbors=30, use_highly_variable=True)
# Out:
# computing moments based on connectivities
#     finished (0:00:05) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)

# %%
######################## part 2.1: Run dynamical model ##########################

# %%
# dynamics model requires to run scv.tl.recover_dynamics(adata, **params) beforehand
scv.tl.recover_dynamics(adata, n_jobs=6)
# Out:
# recovering dynamics (using 6/48 cores)
#   0%|          | 0/466 [00:00<?, ?gene/s]
#     finished (0:04:40) --> added
#     'fit_pars', fitted parameters for splicing dynamics (adata.var)
# /home/yuzhao1/yuzhao1/software/conda/gca-env/lib/python3.8/site-packages/scvelo/tools/dynamical_model.py:713: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.array([dm.alpha, dm.beta, dm.gamma, dm.pars[:3]]) / dm.m[-1]
# /home/yuzhao1/yuzhao1/software/conda/gca-env/lib/python3.8/site-packages/scvelo/tools/dynamical_model.py:716: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.array([dm.t, dm.tau, dm.t_, dm.pars[4]]) * dm.m[-1]

# %%
# compute velocity
scv.tl.velocity(adata, mode='dynamical')


# !jupyter nbextension enable --py widgetsnbextension

scv.tl.velocity_graph(adata, n_neighbors=30, n_jobs=6)

scv.settings.set_figure_params('scvelo', facecolor='white', dpi=100, frameon=False,
                              figsize = [5,5])
# Out:
# computing velocities
#     finished (0:00:17) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK
# computing velocity graph (using 6/48 cores)
#   0%|          | 0/43358 [00:00<?, ?cells/s]
# /home/yuzhao1/yuzhao1/software/conda/gca-env/lib/python3.8/site-packages/scvelo/core/_parallelize.py:138: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   res = np.array(res) if as_array else res
#     finished (0:00:10) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %%
scv.pl.velocity_embedding_grid(adata, basis='umap', color='anno1', 
                               save=False, title='', scale=0.2)
# Out:
# computing velocity embedding
#     finished (0:00:08) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)

# %%
scv.pl.velocity_embedding_stream(adata, basis='umap', color=['anno1'], density = 1.5, 
                                 min_mass = 3.2, cutoff_perc = 0, save=False, title='',
                                max_length = 6)

# %%
# save dataset as anndata format
adata.write(input_path+'adata_dynamical_output_OriginalUmap.h5ad')

# %%
######################## part 2.2: Run stochastic model ##########################

# %%
scv.tl.velocity(adata, mode='stochastic')

scv.tl.velocity_graph(adata, n_jobs=6)

scv.settings.set_figure_params('scvelo', facecolor='white', dpi=100, frameon=False,
                              figsize = [5,5])
# Out:
# computing velocities
#     finished (0:00:08) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph (using 6/48 cores)
#   0%|          | 0/43358 [00:00<?, ?cells/s]
# /home/yuzhao1/yuzhao1/software/conda/gca-env/lib/python3.8/site-packages/scvelo/core/_parallelize.py:138: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   res = np.array(res) if as_array else res
#     finished (0:00:50) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %%
scv.pl.velocity_embedding_grid(adata, basis='umap', color='anno1', 
                               save=False, title='', scale=0.2)
# Out:
# computing velocity embedding
#     finished (0:00:12) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)

# %%
scv.pl.velocity_embedding_stream(adata, basis='umap', color=['anno1'], 
                                 save=False, title='')

# %%
######################## part 3: visualize ##########################

# %%
# reload dynamical data
adata = sc.read_h5ad(input_path+'adata_dynamical_output.h5ad')

# %%
scv.settings.set_figure_params('scvelo', facecolor='white', dpi=100, frameon=False,
                              figsize = [5,5])

# %%
scv.pl.velocity_embedding_grid(adata, basis='umap', color='anno1', 
                               save=False, title='', scale=0.2)

# %%
scv.pl.velocity_embedding_stream(adata, basis='umap', color=['anno1'], 
                                 save=False, title='')

# %%
############### part 4: downstream analysis ###############

# %%
df = adata.var
df = df[(df['fit_likelihood'] > .1) & df['velocity_genes'] == True]

kwargs = dict(xscale='log', fontsize=16)
with scv.GridSpec(ncols=3) as pl:
    pl.hist(df['fit_alpha'], xlabel='transcription rate', **kwargs)
    pl.hist(df['fit_beta'] * df['fit_scaling'], xlabel='splicing rate', xticks=[.1, .4, 1], **kwargs)
    pl.hist(df['fit_gamma'], xlabel='degradation rate', xticks=[.1, .4, 1], **kwargs)

scv.get_df(adata, 'fit*', dropna=True).head()

# %%
scv.tl.rank_velocity_genes(adata, groupby='anno1', min_corr=.3)
# Out:
# ranking velocity genes
#     finished (0:00:18) --> added
#     'rank_velocity_genes', sorted scores by group ids (adata.uns)
#     'spearmans_score', spearmans correlation scores (adata.var)

# %%
df = scv.DataFrame(adata.uns['rank_velocity_genes']['names'])
df.head(20)
# Out:
#         EC1         EC2      Stem
# 0    SLC8A1       NXPE1     EPHB2
# 1      CUBN       PLCE1      BCL2
# 2     THSD4      EIF4G3    ARID5B
# 3   SLC13A1      CAMK1D     CERS6
# 4     MUC17  AC019330.1      CD44
# 5   CYP2C18       SATB2     DACH1
# 6     MUC13        CLMN     CELF2
# 7      TMC5        FMN1  KIAA1324
# 8   SLC15A1       MECOM     PLCB4
# 9     LPIN2      ZBTB7C     ZNRF3
# 10    NR1H4       RASEF     LRIG1
# 11   INSIG1        CA12      CDK6
# 12    TMCC3     SIPA1L2   PPP1R9A
# 13     APOB        TLE1     CMSS1
# 14   HMGCS1     TFCP2L1      UTRN
# 15     G6PC    ARHGAP44      CHD6
# 16     GBP1       ABCC3     BACE2
# 17     RBP2        MYOF    ZBTB38
# 18  PHYHIPL         HK1     CCND2
# 19    BIRC3       EFNA5       APP

# %%
scv.tl.latent_time(adata)
scv.pl.scatter(adata, color='latent_time', color_map='gnuplot', size=80)
# Out:
# computing terminal states
#     identified 7 regions of root cells and 2 regions of end points .
#     finished (0:00:10) --> added
#     'root_cells', root cells of Markov diffusion process (adata.obs)
#     'end_points', end points of Markov diffusion process (adata.obs)
# computing latent time using root_cells as prior
#     finished (0:00:12) --> added
#     'latent_time', shared time (adata.obs)

# %%
top_genes = adata.var['fit_likelihood'].sort_values(ascending=False).index[:300]
scv.pl.heatmap(adata, var_names=top_genes, sortby='latent_time', col_color='anno1', n_convolve=100)

# %%
top_genes = adata.var['fit_likelihood'].sort_values(ascending=False).index
scv.pl.scatter(adata, color='anno1', basis=top_genes[:15], ncols=5, frameon=False)

# %%
scv.pl.velocity(adata, ['LGR5',  'SATB2', 'APOA4', 'CA2'], ncols=2)

# %%
############### part 5: differential kinetics ###############

# %%
scv.tl.velocity(adata, diff_kinetics=True, mode='stochastic', groupby = 'anno1')
# scv.tl.velocity(adata, diff_kinetics=False, mode='stochastic')
# scv.tl.velocity(adata, diff_kinetics=True, mode='stochastic', groupby='anno1',
#                groups = ['Goblet1', 'Goblet2'])

# %%
scv.tl.velocity_graph(adata, n_jobs=6)

# %%
scv.pl.velocity_embedding_stream(adata, basis='umap', color=['anno1'], 
                                 save=False, title='')

# %%
scv.tl.rank_velocity_genes(adata, groupby='anno1', min_corr=.3)

# %%
df = scv.DataFrame(adata.uns['rank_velocity_genes']['names'])
df.head(5)

# %%
scv.tl.latent_time(adata)
scv.pl.scatter(adata, color='latent_time', color_map='gnuplot', size=80)

# %%
scv.pl.velocity(adata, ['LGR5',  'SATB2', 'APOA4', 'CA2'], ncols=2)

# %%
############### part 6: cellrank ###############
# not suitable for our dataset, they lack a general adaptability

# %%
import cellrank as cr

# %%
cr.tl.terminal_states(adata, cluster_key="anno1", weight_connectivities=0.2)

# %%
cr.pl.terminal_states(adata)

# %%
cr.tl.initial_states(adata, cluster_key="anno1")

# %%
cr.pl.initial_states(adata, discrete=True)

# %%
cr.tl.lineage_drivers(adata)
